# %%
import tweepy
import time
import re
import pytz
from pytz import timezone
from tweepy import OAuthHandler
from nltk.tokenize import word_tokenize
from collections import Counter
from nltk.corpus import stopwords
import string
from nltk import trigrams
import json
 
#nltk.download('bigrams')
#nltk.download('stopwords')
#nltk.download('punkt')

consumer_key = 'gswlPdHuI7e0qWBAT5OavoH1w'
consumer_secret = 'rvWMe0ldojIsYSUISbcqKxFodIl0VeMGSLf8HOWUcSL6qOywgK'
access_token = '27651816-os3dMfworD2o430p66jdr668XVzvAOnz16YZgAtfj'
access_secret = 'cE8cV46N6qrKzWfuIVogYPaeM003hd2VH6Y38S4T39YGs'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['RT', 'rt', 'via', 'I' , 'like']


emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)


emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
        
    )"""
#emoji_pattern = r'/[x{1F601}-x{1F64F}]/u'

regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]


tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

eastern = timezone('US/Eastern')
utc = timezone('UTC')



USERNAME = 'maverick1729'
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)
print (time.strftime("%d/%m/%Y - %H:%M:%S"))

#trafficTweet = tweepy.Cursor(api.search,geocode="35.23059364353262, -80.83763122569508, 100km").items(50)
#
trafficTweet = tweepy.Cursor(api.search,geocode="35.3302,-80.7325,25km").items(50000)

count_all = Counter()

with open("clt_dump.txt", 'a') as f:   
    for tweet in trafficTweet:
    # utc_dt = datetime.utcfromtimestamp(tweet.created_at_in_seconds).replace(tzinfo=pytz.utc)
    #localtime_dt = utc_dt.astimezone(localtime_tz)
        utc_created_at = utc.localize(tweet.created_at)
    #print(word_tokenize(tweet.text))
        ##print(tweet.text)
        json.dump(tweet._json, f)  #dump each to file, f
        f.write("\n")
    ##terms_stop = [term for term in preprocess(tweet.text) if term not in stop and not term.startswith(('#', '@')) and not emoji_pattern.search(term)]
    ##terms_bigram = trigrams(terms_stop)
    ##terms_hash = [term for term in preprocess(tweet.text) if term.startswith('#')]
    #terms_all = [term for term in preprocess(tweet.text)]
    #count_all.update(terms_bigram)
    ##count_all.update(terms_hash)
    #print(preprocess(tweet.text))
    #print (tweet.coordinates,utc_created_at.astimezone(eastern), tweet.text, tweet.user.name)
##print(count_all.most_common(5))


#places = api.geo_search(query="India", granularity="country")
#place_id = places[0].id
#for place in places:
#    print(place.name)
    
#tweets = api.search(q="place:%s" % place_id)
#for tweet in tweets:
    #print (tweet.text + " \n\n " +  tweet.place.name if tweet.place else "Undefined place")
# Out:
# 07/02/2017 - 21:33:18
# Rate limit reached. Sleeping for: 511
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\Users\Matt\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# C:\Users\Matt\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                     # otherwise it looks like a programming error was the cause.
# --> 393                     six.raise_from(e, None)
# ...
