# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                           title  year
# 0                  My Lady Boss  2013
# 1               Folly of Vanity  1924
# 2       The Gambler of the West  1915
# 3  Caleuche: El llamado del Mar  2012
# 4               Parachute Nurse  1942

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
len(titles)
# Out:
# 230621

# %%
len(titles[titles.title.notnull()])
# Out:
# 230621

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles[titles.year.sort(head)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c764aea16233> in <module>()
# ----> 1 titles[titles.year.sort(head)]
#
# NameError: name 'head' is not defined

# %%
titles[titles.year.sort()]
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-d7d2575ee179> in <module>()
# ----> 1 titles[titles.year.sort()]
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\series.py in sort(self, axis, ascending, kind, na_position, inplace)
#    1784
#    1785         return self.sort_values(ascending=ascending, kind=kind,
# -> 1786                                 na_position=na_position, inplace=inplace)
#    1787
#    1788     def order(self, na_last=None, ascending=True, kind='quicksort',
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    1683         # GH 5856/5853
# ...

# %%
titles.year.sort()
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-8d8e12043876> in <module>()
# ----> 1 titles.year.sort()
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\series.py in sort(self, axis, ascending, kind, na_position, inplace)
#    1784
#    1785         return self.sort_values(ascending=ascending, kind=kind,
# -> 1786                                 na_position=na_position, inplace=inplace)
#    1787
#    1788     def order(self, na_last=None, ascending=True, kind='quicksort',
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    1683         # GH 5856/5853
# ...

# %%
titles.sort('year')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                     title  year
# 73888                                          Miss Jerry  1894
# 161992                                 The Startled Lover  1898
# 134082     Reproduction of the Corbett and Jeffries Fight  1899
# 24528                                Family Troubles (II)  1900
# 146354                           Trouble in Hogan's Alley  1900
# 99772   Pierrot's Problem, or How to Make a Fat Wife O...  1900
# 205599                              Soldiers of the Cross  1900
# 147528                                        The Divorce  1903
# 25438                                             Valsons  1905
# 138940                                  La malia dell'oro  1905
# 42906                         The Story of the Kelly Gang  1906
# ...

# %%
titles.sort('year').tail(2)
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                     title  year
# 185654         Gods Heart  2025
# 13941   Settling of Score  2026

# %%
titles.sort('year').head()
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                  title  year
# 73888                                       Miss Jerry  1894
# 161992                              The Startled Lover  1898
# 134082  Reproduction of the Corbett and Jeffries Fight  1899
# 24528                             Family Troubles (II)  1900
# 146354                        Trouble in Hogan's Alley  1900

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
titles[titles.title='Hamlet']
# Out:
#   File "<ipython-input-15-ef0b0901be21>", line 1
#     titles[titles.title='Hamlet']
#                        ^
# SyntaxError: invalid syntax

# %%
titles[titles.title == 'Hamlet']
# Out:
#          title  year
# 13284   Hamlet  1911
# 20434   Hamlet  1987
# 32479   Hamlet  1913
# 34193   Hamlet  1948
# 37558   Hamlet  1964
# 40710   Hamlet  1973
# 43523   Hamlet  2011
# 51182   Hamlet  1990
# 68268   Hamlet  2015
# 69296   Hamlet  1954
# 80065   Hamlet  1921
# 124183  Hamlet  2009
# 131127  Hamlet  1969
# 148916  Hamlet  2014
# 149692  Hamlet  2000
# 156914  Hamlet  1910
# 194003  Hamlet  1976
# 204588  Hamlet  1996

# %%
len(titles[titles.title == 'Hamlet'])
# Out:
# 18

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
len(titles[titles.title == 'North by Nothwest'])
# Out:
# 0

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles.title='Hamlet].sort('year').head(1)
# Out:
#   File "<ipython-input-19-64b8e3800403>", line 1
#     titles[titles.title='Hamlet].sort('year').head(1)
#                        ^
# SyntaxError: invalid syntax

# %%
titles[titles.title=='Hamlet].sort('year').head(1)
# Out:
#   File "<ipython-input-20-01a2d570f58d>", line 1
#     titles[titles.title=='Hamlet].sort('year').head(1)
#                                            ^
# SyntaxError: invalid syntax

# %%
titles[titles.title=='Hamlet'].sort('year').head(1)
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#          title  year
# 156914  Hamlet  1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles.[title.title=='Treasure Island'].sort('year')
# Out:
#   File "<ipython-input-22-70a10304dafd>", line 1
#     titles.[title.title=='Treasure Island'].sort('year')
#            ^
# SyntaxError: invalid syntax

# %%
titles.[titles.title=='Treasure Island'].sort('year')
# Out:
#   File "<ipython-input-23-12a5a5be8efa>", line 1
#     titles.[titles.title=='Treasure Island'].sort('year')
#            ^
# SyntaxError: invalid syntax

# %%
titles[titles.title=='Treasure Island'].sort('year')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                   title  year
# 84688   Treasure Island  1918
# 111141  Treasure Island  1920
# 104375  Treasure Island  1934
# 131555  Treasure Island  1950
# 32879   Treasure Island  1972
# 61465   Treasure Island  1973
# 123207  Treasure Island  1985
# 72540   Treasure Island  1999

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
len(titles[titles.year==1950]))
# Out:
#   File "<ipython-input-25-80db5f2d4327>", line 1
#     len(titles[titles.year==1950]))
#                                   ^
# SyntaxError: invalid syntax

# %%
len(titles[titles.year==1950])
# Out:
# 1093

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
len(titles[titles.year==1960])
# Out:
# 1496

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len(titles[(titles.year>=1950]) & (titles.year<=1959])])
# Out:
#   File "<ipython-input-28-56a64ae3e453>", line 1
#     len(titles[(titles.year>=1950]) & (titles.year<=1959])])
#                                  ^
# SyntaxError: invalid syntax

# %%
len(titles[(titles.year>=1950) & (titles.year<=1959)])
# Out:
# 12656

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles.title='Batman'].year
# Out:
#   File "<ipython-input-30-e11e2499c07f>", line 1
#     titles[titles.title='Batman'].year
#                        ^
# SyntaxError: invalid syntax

# %%
titles[titles.title=='Batman'].year
# Out:
# 23511     1943
# 190161    1989
# Name: year, dtype: int64

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast
# Out:
#                                                      title  year  \
# 0                                           Closet Monster  2015
# 1                                          Suuri illusioni  1985
# 2                                      Battle of the Sexes  2017
# 3                                     Secret in Their Eyes  2015
# 4                                               Steve Jobs  2015
# 5                                   Straight Outta Compton  2015
# 6                                   Straight Outta Compton  2015
# 7                                           For Thy Love 2  2009
# 8        Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                             Desire (III)  2014
# 10                                 When the Man Went South  2014
# 11                                 Little Angel (Angelita)  2015
# 12                                              Mixing Nia  1998
# ...

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
cast[cast.title='Inception'].roles
# Out:
#   File "<ipython-input-34-5438554d953d>", line 2
#     cast[cast.title='Inception'].roles
#                    ^
# SyntaxError: invalid syntax

# %%
cast[cast.title=='Inception'].roles
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-5a28e4dee751> in <module>()
# ----> 1 cast[cast.title=='Inception'].roles
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'roles'

# %%
cast[cast.title=='Inception']
# Out:
#              title  year                     name     type  \
# 94333    Inception  2010     Michael (III) August    actor
# 143138   Inception  2010             Peter Basham    actor
# 176819   Inception  2010             Tom Berenger    actor
# 190249   Inception  2010                 Ken Bhan    actor
# 250191   Inception  2010           Virgile Bramly    actor
# 314663   Inception  2010            Michael Caine    actor
# 321091   Inception  2010             Earl Cameron    actor
# 361119   Inception  2010            John Ceallach    actor
# 417982   Inception  2010            Nicolas Clerc    actor
# 428199   Inception  2010           Adam (IV) Cole    actor
# 498708   Inception  2010       Jean-Michel Dagory    actor
# 569504   Inception  2010        Leonardo DiCaprio    actor
# 659835   Inception  2010            Seve Esposito    actor
# 666157   Inception  2010      Marcus (II) Everett    actor
# 682511   Inception  2010  Zachary Christopher Fay    actor
# ...

# %%
len(cast[cast.title=='Inception'])
# Out:
# 70

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
len(cast[(cast.title=='Inception') | (cast.n='NaN')])
# Out:
#   File "<ipython-input-38-d1bae4ab5f78>", line 1
#     len(cast[(cast.title=='Inception') | (cast.n='NaN')])
#                                                 ^
# SyntaxError: invalid syntax

# %%
len(cast[(cast.title=='Inception') | (cast.n='NaN')])len(cast[(cast.title=='Inception') | (cast.n=='NaN')])
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py:716: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-7551d726493b> in <module>()
# ----> 1 len(cast[(cast.title=='Inception') | (cast.n=='NaN')])
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     761                 other = np.asarray(other)
#     762
# --> 763             res = na_op(values, other)
#     764             if isscalar(res):
#     765                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     716                 result = getattr(x, name)(y)
# ...

# %%
ln(cast[(cast.title=='Inception') | (cast.n.isnull())])e
# Out:
# 1189220

# %%
len(cast[(cast.title=='Inception') & (cast.n.isnull())])
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[cast.title=='North by Northwest' & !(cast.n.isnull())]]
# Out:
#   File "<ipython-input-42-bb20643e7f26>", line 1
#     cast[cast.title=='North by Northwest' & !(cast.n.isnull())]]
#                                             ^
# SyntaxError: invalid syntax

# %%
cast[cast.title=='North by Northwest' & (cast.n.notnull())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     784         try:
# --> 785             result = op(x, y)
#     786         except TypeError:
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x, y)
#     118                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 119                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     120                                    names('rand_'), op('&')),
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
cast[cast.title=='North by Northwest' & (cast.n.isnull())]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     784         try:
# --> 785             result = op(x, y)
#     786         except TypeError:
#
# C:\Users\Mathew\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x, y)
#     118                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 119                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     120                                    names('rand_'), op('&')),
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
cast[(cast.title=='Inception') & (cast.n.isnull())]
# Out:
#              title  year                     name     type  \
# 94333    Inception  2010     Michael (III) August    actor
# 190249   Inception  2010                 Ken Bhan    actor
# 361119   Inception  2010            John Ceallach    actor
# 659835   Inception  2010            Seve Esposito    actor
# 666157   Inception  2010      Marcus (II) Everett    actor
# 682511   Inception  2010  Zachary Christopher Fay    actor
# 806524   Inception  2010        Daniel Girondeaud    actor
# 971196   Inception  2010          Andrew Hoagland    actor
# 1056651  Inception  2010          Charles Jarrell    actor
# 1069724  Inception  2010            Seong-hwan Jo    actor
# 1080743  Inception  2010          Alonzo F. Jones    actor
# 1146809  Inception  2010               Mobin Khan    actor
# 1203175  Inception  2010            Shunsaku Kud?    actor
# 1249439  Inception  2010         John (IX) Lawson    actor
# 1264919  Inception  2010    Jean-Christophe Leger    actor
# ...

# %%
cast[(cast.title=='North by Northwest') & (cast.n.isnull())]
# Out:
#                       title  year                 name     type  \
# 12151    North by Northwest  1959        Stanley Adams    actor
# 27852    North by Northwest  1959           Andy Albin    actor
# 54093    North by Northwest  1959         Don Anderson    actor
# 54307    North by Northwest  1959      Ernest Anderson    actor
# 92195    North by Northwest  1959    Malcolm Atterbury    actor
# 97833    North by Northwest  1959            Tol Avery    actor
# 109025   North by Northwest  1959           Sam Bagley    actor
# 114334   North by Northwest  1959          Frank Baker    actor
# 137656   North by Northwest  1959        Baynes Barron    actor
# 151717   North by Northwest  1959        Brandon Beach    actor
# 176030   North by Northwest  1959        John Beradino    actor
# 222299   North by Northwest  1959      Stephen Bolster    actor
# 344204   North by Northwest  1959     Steve Carruthers    actor
# 350192   North by Northwest  1959        Taggart Casey    actor
# ...

# %%
cast[(cast.title=='Inception') & !(cast.n.isnull())]
# Out:
#   File "<ipython-input-47-517d9ea40a6a>", line 2
#     cast[(cast.title=='Inception') & !(cast.n.isnull())]
#                                      ^
# SyntaxError: invalid syntax

# %%
cast[(cast.title=='Inception') & ~(cast.n.isnull())]
# Out:
#              title  year                  name     type  \
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 250191   Inception  2010        Virgile Bramly    actor
# 314663   Inception  2010         Michael Caine    actor
# 321091   Inception  2010          Earl Cameron    actor
# 417982   Inception  2010         Nicolas Clerc    actor
# 428199   Inception  2010        Adam (IV) Cole    actor
# 498708   Inception  2010    Jean-Michel Dagory    actor
# 569504   Inception  2010     Leonardo DiCaprio    actor
# 684215   Inception  2010             Russ Fega    actor
# 711192   Inception  2010      Mark Fleischmann    actor
# 779284   Inception  2010        Michael Gaston    actor
# 783405   Inception  2010       Johnathan Geare    actor
# 802478   Inception  2010         Carl Gilliard    actor
# 803728   Inception  2010           Jack Gilroy    actor
# 829338   Inception  2010  Joseph Gordon-Levitt    actor
# ...

# %%
cast[(cast.title=='Inception') & ~(cast.n.isnull())].sort('n')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#              title  year                  name     type  \
# 569504   Inception  2010     Leonardo DiCaprio    actor
# 829338   Inception  2010  Joseph Gordon-Levitt    actor
# 907468   Inception  2010             Tom Hardy    actor
# 2318555  Inception  2010          Ken Watanabe    actor
# 1808640  Inception  2010            Dileep Rao    actor
# 1558174  Inception  2010        Cillian Murphy    actor
# 176819   Inception  2010          Tom Berenger    actor
# 2658136  Inception  2010      Marion Cotillard  actress
# 1760521  Inception  2010    Pete Postlethwaite    actor
# 314663   Inception  2010         Michael Caine    actor
# 878274   Inception  2010            Lukas Haas    actor
# 1262529  Inception  2010            Tai-Li Lee    actor
# 2814544  Inception  2010          Claire Geare  actress
# ...

# %%
cast[(cast.title=='North by Northwest') & ~(cast.n.isnull())].sort('n')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                       title  year                  name     type  \
# 840374   North by Northwest  1959            Cary Grant    actor
# 1404704  North by Northwest  1959           James Mason    actor
# 3024085  North by Northwest  1959   Jessie Royce Landis  actress
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 2923056  North by Northwest  1959  Josephine Hutchinson  actress
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast.title=='Sleuth') & ~(cast.n.isnull()) & cast.year == 1972].sort('n')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %%
vcast[(cast.title=='Sleuth') & ~(cast.n.isnull()) & cast.year == 1972].sort('n')cast[(cast.title=='Sleuth') & cast.year == 1972].sort('n')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %%
cast[(cast.title=='Sleuth')]
# Out:
#           title  year                 name     type  \
# 250297   Sleuth  2007      Kenneth Branagh    actor
# 314691   Sleuth  1972        Michael Caine    actor
# 314692   Sleuth  2007        Michael Caine    actor
# 360365   Sleuth  1972       Alec Cawthorne    actor
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor
# 1246855  Sleuth  2007             Jude Law    actor
# 1396572  Sleuth  1972         Teddy Martin    actor
# 1412647  Sleuth  1972   John (II) Matthews    actor
# 1644328  Sleuth  1972     Laurence Olivier    actor
# 1741124  Sleuth  2007        Harold Pinter    actor
# 2619277  Sleuth  2007    Eve (II) Channing  actress
# 2619278  Sleuth  1972   Eve (III) Channing  actress
#
#                           character    n
# 250297            Other Man on T.V.  NaN
# 314691                  Milo Tindle  2.0
# 314692                       Andrew  1.0
# 360365            Inspector Doppler  3.0
# 360366            Inspector Doppler  NaN
# ...

# %%
cast[(cast.title=='Sleuth') &  (cast.year == 1972)]
# Out:
#           title  year                name     type  \
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1396572  Sleuth  1972        Teddy Martin    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
#
#                           character    n
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1396572      Police Constable Higgs  6.0
# 1412647  Detective Sergeant Tarrant  4.0
# 1644328                 Andrew Wyke  1.0
# 2619278             Marguerite Wyke  5.0

# %%
cast[(cast.title=='Sleuth') &  (cast.year == 1972)].sort('n')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#           title  year                name     type  \
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
# 1396572  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 2619278             Marguerite Wyke  5.0
# 1396572      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast.title=='Sleuth') &  (cast.year == 2007)].sort('n')
# Out:
# C:\Users\Mathew\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           title  year                 name     type          character    n
# 314692   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast.title=='Hamlet') &  (cast.year == 1921)]
# Out:
#           title  year                    name     type         character    n
# 7438     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 442224   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 535307   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1095274  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2106367  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2289163  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2562876  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2935728  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %% [markdown]
# ### How many roles has Judi Dench played?

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
cast.tail()
# Out:
#                       title  year         name     type        character    n
# 3088762  Female Perversions  1996  Amy Madigan  actress  Maddie Stephens  2.0
# 3088763     Field of Dreams  1989  Amy Madigan  actress   Annie Kinsella  2.0
# 3088764            Frontera  2014  Amy Madigan  actress           Olivia  4.0
# 3088765      Future Weather  2012  Amy Madigan  actress            Greta  3.0
# 3088766         Gary's Walk  2009  Amy Madigan  actress           Gloria  NaN

# %%
cast[(cast.name == 'Cary Grant') & (cast.year == 1940) & (cast.n == 2) ]
# Out:
#                    title  year        name   type character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor      Nick  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?
